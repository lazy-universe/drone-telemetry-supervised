# %% [markdown]
# # Reproducibility Manifest 3: Robustness & Debouncing
#
# This notebook executes the final steps from `RUN_ORDER.md` to regenerate the debouncing sweeps (Table 13), latency benchmarks, and final assertions.

# %%
from pathlib import Path
import os
PROJECT_ROOT = Path("..").resolve()
os.chdir(PROJECT_ROOT)
print("Operating Directory:", os.getcwd())

# %% [markdown]
# ### Step 10 — Alarm Debouncing Sweep (Table 13)
# *(Requires `flight_ids_test.npy` generated in Step 1)*

# %%
# !python presets/run_debounce_eval.py --split flight --mode baseline

# %% [markdown]
# ### Threshold tuning graph

# %%
# !python presets/run_plot_val_threshold_curves.py --split flight --feature-mode engineered --model-type sequence
# !python presets/run_plot_val_threshold_curves.py --split flight --feature-mode engineered --model-type pointwise
