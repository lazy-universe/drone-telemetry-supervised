# %% [markdown]
# # Reproducibility Manifest 2: Ablations
#
# This notebook executes steps 6-9 from `RUN_ORDER.md` to regenerate the ablation tables (Tables 9-12).

# %%
from pathlib import Path
import os
PROJECT_ROOT = Path("..").resolve()
os.chdir(PROJECT_ROOT)
print("Operating Directory:", os.getcwd())

# %% [markdown]
# ### Step 6 — Feature Ablation Study (Table 9)

# %%
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all --exclude-features "prediction_error"
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all --exclude-features "motion_smoothness"
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all --exclude-features "heading_speed_consistency"
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all --exclude-features "ground_speed"

# %% [markdown]
# ### Step 7 — Feature Representation Comparison (Table 10)

# %%
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all --feature-mode raw

# %% [markdown]
# ### Step 8 — Selected Kinematic Feature Subsets (Table 11)

# %%
# PE Only
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all --exclude-features "ground_speed,vertical_acceleration,vertical_speed,acceleration,turn_rate,path_curvature,heading_speed_consistency,motion_smoothness"

# PE + HSC
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all --exclude-features "ground_speed,vertical_acceleration,vertical_speed,acceleration,turn_rate,path_curvature,motion_smoothness"

# PE + HSC + GS
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all --exclude-features "vertical_acceleration,vertical_speed,acceleration,turn_rate,path_curvature,motion_smoothness"

# PE + HSC + GS + MS
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all --exclude-features "vertical_acceleration,vertical_speed,acceleration,turn_rate,path_curvature"

# %% [markdown]
# ### Step 9 — Window Length Analysis (Table 12)

# %%
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models sequence --window-size 5
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models sequence --window-size 10
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models sequence --window-size 15
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models sequence --window-size 30

# %% [markdown]
# ### Just for Validating Results with same baseline configuration

# %%
## These are just for validation (no mismatch across results for same configuration)
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models sequence --window-size 20
