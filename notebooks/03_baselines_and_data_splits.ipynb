# %% [markdown]
# # Reproducibility Manifest 1: Baselines & Splits
#
# This notebook executes the first 5 steps of `RUN_ORDER.md` to regenerate Tables 2-8 from the paper. Using the `!python` subprocess syntax guarantees that there is zero Jupyter state leakage.

# %%
from pathlib import Path
import os
PROJECT_ROOT = Path("..").resolve()
os.chdir(PROJECT_ROOT)
print("Operating Directory:", os.getcwd())

# %% [markdown]
# ### Step 1 — Baseline Performance (Tables 2, 3, 4)

# %%
# !python presets/run_unified_supervised_classification.py --split-mode random --seed 42 --models all
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all
# !python presets/run_unified_supervised_classification.py --split-mode device --seed 42 --models all

# %% [markdown]
# ### Step 2 — Tuned Threshold Performance (Table 5)

# %%
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all --tune

# %% [markdown]
# ### Step 3 — Leave-One-Attack-Out (LOAO) Generalization (Table 6)

# %%
# !python presets/run_leave_one_attack_out.py

# %% [markdown]
# ### Step 4 — 5-Fold Stratified Cross-Validation (Table 7)

# %%
# !python presets/run_unified_supervised_classification.py --split-mode flight --seed 42 --models all --cv

# %% [markdown]
# ### Step 5 — Multi-Seed Stability Analysis (Table 8)
# *(Runs automatically against seeds 17, 42, 137, 521, 2026)*

# %%
# !python presets/run_seed_experiment.py --split flight
